# %% [markdown]
# # Problem Statement

# %% [markdown]
# # Loading the dataset from kaggle

# %%
import kagglehub
path = kagglehub.dataset_download("aryashah2k/breast-ultrasound-images-dataset")
# Out:
# Using Colab cache for faster access to the 'breast-ultrasound-images-dataset' dataset.

# %% [markdown]
# # Importing the dependecies

# %%
import os
import cv2
import shutil
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.metrics import classification_report, confusion_matrix

# %% [markdown]
# # Preparing the dataset

# %%
print(os.listdir(path))
# Out:
# ['Dataset_BUSI_with_GT']

# %%
busi_path = os.path.join(path, "Dataset_BUSI_with_GT")
os.listdir(busi_path)
# Out:
# ['benign', 'normal', 'malignant']

# %%
classes = ["benign", "malignant", "normal"]

# %%
# now storing images in corrosponding variables
benign_img = []
malignant_img = []
normal_img = []

for cls in classes:
    cls_path = os.path.join(base_path, cls)

    for file in os.listdir(cls_path):
        if "mask" in file.lower():
            continue

        img = cv2.imread(os.path.join(cls_path, file))
        img = cv2.resize(img, (128, 128))

        if cls == "benign":
            benign_img.append(img)
        elif cls == "malignant":
            malignant_img.append(img)
        else:
            normal_img.append(img)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2123959211.py in <cell line: 0>()
# ----> 1 print(benign)
#
# NameError: name 'benign' is not defined
